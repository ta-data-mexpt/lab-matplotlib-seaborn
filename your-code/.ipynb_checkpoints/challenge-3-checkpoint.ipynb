# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(['int','float']).head(5)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(object).head(5)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# plot style to classic
plt.style.use('classic')

# plot style to whitegrid
sns.set_style('whitegrid')

# plot figure size parameters size (12,6)
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
plt.xlabel('Age')
plt.ylabel('People')
titanic['Age'].hist(bins=50)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='People'>

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

plt.subplot(1,3,1)
titanic['Age'].hist(bins=10)
plt.ylabel('# de personas')
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.xlabel('edad')
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#The bin size does not affect my plot, it just gives me more detail 
#mientras mayor sea el bin, mayor detalle tendremos

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.histplot(titanic['Age'],bins=30, kde=False, color='red', alpha=0.5)
plt.legend(['prueba'], loc=1)
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# your code here- 1st way
plt.xlabel('Gender')
plt.ylabel('People')
titanic['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='People'>

# %%
# your code here- 2nd way
#countplot sirve para que de una columna, separemos sus valores únicos
sns.countplot(x='Gender',data=titanic)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
#countplot sirve para que de una columna, separemos sus valores únicos
sns.countplot(x='Pclass',data=titanic)
plt.xlabel('Passengers class')
# Out:
# Text(0.5, 0, 'Passengers class')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
#en boxplot, tenemos el quartil25, quartil75, la media y los outliers
titanic.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#la edad media de los pasajeros es de +- 29 años 
#El 25% de los pasajeros esta por debajo de los 22 años y el 75% esta por debajo de los +-38 años
#Hay algunos casos fuera de rango que estan por arriba de los 59 años

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.violinplot(x=titanic["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#la mayoría de los pasajeros esta en un rango de edad entre los 20 y 40 años 
#hay muy pocos pasajeros que tienen por arriba de los 60 años

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
titanic['Fare'].corr(titanic['Age'])
#no hay correlación
# Out:
# 0.17135508596244756

# %%
# your code-2nd way
#etiquetas para eje x
plt.xlabel('Edad', fontsize=10)
#etiquetas para eje y
plt.ylabel('Tarifa', fontsize=10)
#cuadricula
plt.grid(True)
plt.scatter(x=titanic['Age'], y=titanic['Fare'])

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
# Correlation matrix'

plt.title('Correlation matrix')
cmap = sns.diverging_palette(6,255,as_cmap=True)
sns.heatmap(titanic.corr(), cmap=cmap, annot=True)
#mas rojo, correlación negativa
# Out:
# <AxesSubplot:title={'center':'Correlation matrix'}>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#SibSp con parch estan levemente correlacionados de manera positiva
#Pclass y Fare estan correlacionados de manera negativa

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')
plt.xlabel('Passengers class')
# Out:
# Text(0.5, 0, 'Passengers class')

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(data=titanic,col='Gender')
g.map(plt.hist,'Age')
#hay más hombres pasajeros que mujeres
#la mayoría de los hombres estan entre los 25-30 años
#la mayoría de las mujeres estan entre los 25-30 años
