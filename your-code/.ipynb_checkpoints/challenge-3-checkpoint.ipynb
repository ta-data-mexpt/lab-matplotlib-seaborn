# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('titanic.csv',low_memory=False)
titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender   Age  SibSp  \
# 0            1       0.0       3  Braund, Mr. Owen Harris   male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
list(titanic.select_dtypes(include=['int64','float64']).columns)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
#your code here- categorical variable
list(titanic.select_dtypes(exclude=['int64','float64']).columns)
# Out:
# ['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import seaborn as sns
plt.figure(figsize = (12, 6))
plt.hist(titanic.Age, bins = 30)
plt.show()

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')
plt.figure(figsize = (12, 6))
# your code here
titanic['Age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.style.use('classic')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
titanic['Age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
sns.histplot(titanic.Age)
#plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.subplot(1,3,1)
titanic['Age'].hist(bins=10)
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

Por la cantidad de intervalos de edad que se definen, entre mas intervalos, mayor cantidad de barras, y al mismo tiempo
menor es la cantidas dentro de cada intervalo, en el primer caso de 20 a 30, estan casi 350 personas, y en el de la ultima grafica
esta entre 34 y 36, como 110 personas
# Out:
#   File "C:\Users\sistemas\AppData\Local\Temp\ipykernel_9548\570658448.py", line 3
#     Por la cantidad de intervalos de edad que se definen, entre mas intervalos, mayor cantidad de barras, y al mismo tiempo
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
plt.figure(figsize = (10, 6))
sns.histplot(titanic.Age, bins = 50, color = 'r')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic.Gender.value_counts()
plt.figure(figsize = (10, 6))
sns.histplot(titanic.Gender, bins = 50, color = 'r')
#plt.xticks(rotation = 90)
plt.show()

# %%
# your code here- 2nd way
sns.countplot(x='Gender',data=titanic)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
titanic.Gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic.Pclass

titanic.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name Gender   Age  SibSp  \
# 0            1       0.0       3  Braund, Mr. Owen Harris   male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25    U0        S

# %%
titanic['Pclass'].value_counts().plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
list(titanic['Pclass'].value_counts().index)

plt.figure(figsize = (10, 10))
plt.pie(list(titanic['Pclass'].value_counts()), 
        labels = list(titanic['Pclass'].value_counts().index),
       autopct = '%0.2f%%')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
LA EDAD MEDIA ESTA COMO POR LOS 29
PRIMER CUARTIL ESTA EN LOS 22
TERCER CUARTIL ESTA EN LOS 37
la mayoria de las personas estan de entre 0 y 59 años, 
depues de estas edades son valores atipicos.
# Out:
#   File "C:\Users\sistemas\AppData\Local\Temp\ipykernel_9548\1635555172.py", line 2
#     LA EDAD MEDIA ESTA COMO POR LOS 29
#        ^
# SyntaxError: invalid syntax

# %%
titanic.Age.describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
titanic.Age.min()
# Out:
# 0.17

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code hesre
plt.figure(figsize = (10, 6))
sns.histplot(titanic.Age, bins = 50, color = 'r')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.violinplot("Age", data=titanic)
# Out:
# C:\Users\sistemas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# #your comment here
# # Dibuje una combinación de diagrama de caja y estimación de densidad kernel.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.plot(titanic.Fare, titanic.Age, marker = 'D', linestyle = ':',
         markerfacecolor ='tab:pink', markeredgecolor ='c', c='red')
    
#plt.scatter(titanic.Fare, titanic.Age, c='b', marker = '+', alpha = 0.05)

# %%
# your code-2nd way
# your code-2nd way
sns.jointplot(x='Fare',y='Age',data=titanic)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %%
mask = np.triu(np.ones_like(titanic.corr(), dtype = bool))
cmap = sns.diverging_palette(2020, 10, as_cmap = True)
cmap

# %%
plt.figure(figsize = (10, 10))
sns.heatmap(titanic.corr(), mask = mask, cmap = cmap)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
