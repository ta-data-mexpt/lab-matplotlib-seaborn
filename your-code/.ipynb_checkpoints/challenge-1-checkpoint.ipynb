# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('X - Y')
plt.subplot(1,2,2)
plt.plot(x,z)
plt.title('X - Z')
# Out:
# Text(0.5, 1.0, 'X - Z')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.plot(x,y)
ax2.plot(x,z)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(2, figsize=(10,5))
ax1.plot(x,y)
ax2.plot(x,z)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(2, figsize=(10,5))
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.plot(x,y)

ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.plot(x,z)

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
vehicles = pd.read_csv('vehicles.csv')

# %%
x = vehicles['Combined MPG']
y = vehicles['Highway MPG']
plt.figure(figsize = (10, 5))
plt.scatter(x = x, y = y)
plt.xlabel('Combined MPG')
plt.ylabel('Highway MPG')
plt.title('Combined MPG - Highway MPG')
# Out:
# Text(0.5, 1.0, 'Combined MPG - Highway MPG')

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.boxplot(vehicles['CO2 Emission Grams/Mile'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1013358b0>,
#   <matplotlib.lines.Line2D at 0x101335c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x101335f70>,
#   <matplotlib.lines.Line2D at 0x101341310>],
#  'boxes': [<matplotlib.lines.Line2D at 0x101335550>],
#  'medians': [<matplotlib.lines.Line2D at 0x101341670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1013419d0>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.figure(figsize = (15, 5))
plt.hist(data = vehicles, x = 'Fuel Barrels/Year', bins = 25, ec = 'black')
# Out:
# (array([6.300e+01, 1.000e+01, 1.800e+01, 6.700e+01, 2.970e+02, 1.126e+03,
#         4.059e+03, 5.600e+03, 6.259e+03, 6.760e+03, 4.613e+03, 2.413e+03,
#         2.026e+03, 1.275e+03, 7.350e+02, 4.390e+02, 0.000e+00, 1.300e+02,
#         0.000e+00, 3.600e+01, 0.000e+00, 2.100e+01, 0.000e+00, 0.000e+00,
#         5.000e+00]),
#  array([ 0.06      ,  1.94108571,  3.82217143,  5.70325714,  7.58434286,
#          9.46542857, 11.34651429, 13.2276    , 15.10868571, 16.98977143,
#         18.87085714, 20.75194286, 22.63302857, 24.51411429, 26.3952    ,
#         28.27628571, 30.15737143, 32.03845714, 33.91954286, 35.80062857,
#         37.68171429, 39.5628    , 41.44388571, 43.32497143, 45.20605714,
#         47.08714286]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
plt.figure(figsize = (15, 8))
plt.bar(x = vehicles['Fuel Type'], height = vehicles['City MPG'])
# Out:
# <BarContainer object of 35952 artists>
