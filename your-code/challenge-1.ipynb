# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x,y,lw=3,color="g", ls='-')
plt.subplot(1,2,2)
plt.plot(x,z,lw=3, color="b",ls='--')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig,axes=plt.subplots(1,2)
axes[0].plot(x,y,color="g", lw=3, ls='-')
axes[1].plot(x,z,color="b", lw=3, ls='--')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(12,2))
axes[0].plot(x,y,color="g", lw=3, ls='-')
axes[1].plot(x,z,color="b", lw=3, ls='--')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,2))

axes[0].plot(x,y,color="blue", lw=5)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,z,color="red", lw=3, ls='--')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, axes = plt.subplots(1, 2, figsize=(8,5))
      
axes[0].plot(x**2, np.exp(x))
axes[0].set_title("Escala normal")
axes[0].set_yscale("linear")


axes[1].plot(x**2, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Escala log")
# Out:
# Text(0.5, 1.0, 'Escala log')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv('vehicles.csv')
plt.scatter(df['Combined MPG'],df['Highway MPG'],s=10,c='r')

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.boxplot(df['CO2 Emission Grams/Mile'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d593e723d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d593e72970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d593e5fe50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d593e72f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d593e7f220>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(df['Fuel Barrels/Year'])
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Fuel Barrels', fontsize = 15)
# Out:
# Text(0, 0.5, 'Fuel Barrels')

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
#en este caso se tarda mucho en correr, creo que podriamos hacer algo de limpieza antes de plotear
df['Fuel Type'] = df['Fuel Type'].str.replace('Gasoline or E85', 'Regular')
df['Fuel Type'] = df['Fuel Type'].str.replace('Gasoline or natural gas', 'Regular')
df['Fuel Type'] = df['Fuel Type'].str.replace('Midgrade', 'Regular')
df['Fuel Type'] = df['Fuel Type'].str.replace('Gasoline or propane', 'Regular')
df['Fuel Type'] = df['Fuel Type'].str.replace('Premium or E85', 'Premium')


df['Fuel Type'].value_counts()
# Out:
# Regular                        24884
# Premium                        10042
# Diesel                           911
# CNG                               60
# Premium and Electricity           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Regular Gas or Electricity         2
# Name: Fuel Type, dtype: int64

# %%
plt.bar(df['Fuel Type'],df['City MPG'])
plt.xlabel('Fuel Type', fontsize = 15)
plt.ylabel('City MPG', fontsize = 15)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
