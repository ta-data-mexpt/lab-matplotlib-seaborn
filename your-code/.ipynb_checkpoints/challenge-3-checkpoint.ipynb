# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=['float', 'int64']).head(4)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000

# %%
#your code here- categorical variable
titanic.select_dtypes(include=['object']).head(4)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist();

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.subplot(1, 3, 1)
titanic['Age'].hist(bins=10)

plt.subplot(1, 3, 2)
titanic['Age'].hist(bins=20)

plt.subplot(1, 3, 3)
titanic['Age'].hist(bins=50)

;
# Out:
# ''

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

# %% [markdown]
# Yes, it affects the range of the y-axis. As bins become more numerous, and thus smaller in size, less data points are grouped in the same bin.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.histplot(data=titanic['Age']);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
print(titanic['Gender'].value_counts())
print(len(titanic['Gender']))
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64
# 1309

# %%
num_male = len(titanic.loc[titanic['Gender'] == 'male', 'Gender'])
num_female = len(titanic.loc[titanic['Gender'] == 'female', 'Gender'])
total = len(titanic['Gender'])
labelss = ['Male', 'Female']
sizes = [(num_male/total*100), (num_female/total*100)]
sizes
# Out:
# [64.40030557677616, 35.59969442322384]

# %%
plt.pie(sizes, explode = (0, 0.05),  autopct='%1.1f%%', labels=labelss, startangle=220);

# %%
# your code here- 2nd way
sns.displot(titanic['Gender']);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
x = titanic['Pclass'].value_counts().sort_values().astype('object')
x
# Out:
# 2    277
# 1    323
# 3    709
# Name: Pclass, dtype: object

# %%
# your code here
pclass = titanic['Pclass'].astype('object')
sns.displot(x);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
sns.boxplot(data=titanic, x='Age');

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %% [markdown]
# La mayoría de las personas tenían entre 20 y 40 años. A su vez, hay varios outliers, que tienen más de 60 años.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.histplot(data=titanic, x='Age');

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# La mayor parte de las personas tenían un poco más de 20 años y 30 o menos de 30 años. Es decir, que en el accidente del Titanic principalmente muriéron personas jóvenes.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.scatterplot(data=titanic, x='Age', y='Fare');

# %%
# your code-2nd way
plt.scatter(x=titanic['Age'], y=titanic['Fare']);

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
titanic_matrix = titanic.corr()
sns.heatmap(titanic_matrix, cmap='Blues');

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# The most correlated features are:
# - SibSp and Parch
# - Survived and Fare
#
# Which means that the most wealthy were the most likely to survide. Sad...

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x='Age', y='Pclass', data=titanic, orient='h');

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
g = sns.FacetGrid(data=titanic, col='Gender')
g.map(sns.histplot, 'Age');
