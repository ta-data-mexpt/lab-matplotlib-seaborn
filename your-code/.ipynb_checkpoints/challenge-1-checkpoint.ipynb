# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#'''

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,20)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
#'#FFD700'
subplot1 = plt.subplot(2, 1, 1)
subplot2 = plt.subplot(2, 1, 2)

subplot1.plot(x, y, marker = '$f$', linestyle = ':',
         markerfacecolor ='darkviolet', markeredgecolor ='b', c='darkviolet')

subplot2.plot(x, z, marker = 'D', linestyle = ':',
         markerfacecolor ='tab:pink', markeredgecolor ='c', c='red')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, axis = plt.subplots(2, 1)
axis[0].plot(x, y, marker = ',', linestyle = ':',
         markerfacecolor ='#FFD700', markeredgecolor ='#FFD700', c='goldenrod')
axis[1].plot(x, z, marker = '*', linestyle = '--',
         markerfacecolor ='#FFD700', markeredgecolor ='#FFD700', c='goldenrod')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, axis = plt.subplots(2, 1, figsize = (10,5))
axis[0].plot(x, y, marker = '$f$', linestyle = ':',
         markerfacecolor ='darkviolet', markeredgecolor ='b', c='darkviolet')
axis[1].plot(x, z,  marker = 'D', linestyle = ':',
         markerfacecolor ='tab:pink', markeredgecolor ='c', c='red')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here

fig, axis = plt.subplots(2, 1, figsize = (10,5))
axis[0].plot(x, y, marker = '$f$', linestyle = ':',
         markerfacecolor ='darkviolet', markeredgecolor ='b', c='darkviolet')

axis[0].set_xlabel("X axis label")
axis[0].set_ylabel("Y axis label")



axis[1].plot(x, z,  marker = 'D', linestyle = ':',
         markerfacecolor ='tab:pink', markeredgecolor ='c', c='red')

axis[1].set_xlabel("X axis label")
axis[1].set_ylabel("Z axis label")
# Out:
# Text(0, 0.5, 'Z axis label')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
import numpy as np
import math

fig, axis = plt.subplots(2, 1, figsize = (10,5))


axis[0].plot(x, x**2, marker = '$f$', linestyle = ':',
         markerfacecolor ='darkviolet', markeredgecolor ='b', c='darkviolet',label = 'Y = X^2' )

axis[0].set_xlabel("X axis label")
axis[0].set_ylabel("Y axis label")
axis[0].set_xscale('log')
axis[0].set_yscale('log')
axis[0].legend()

axis[1].plot(x, [math.exp(item) for item in x],  marker = 'D', linestyle = ':',
         markerfacecolor ='tab:pink', markeredgecolor ='c', c='red',label = 'Y = EXP(X)' )
axis[1].legend()
axis[1].set_xlabel("X axis label")
axis[1].set_ylabel("Z axis label")
axis[1].set_xscale('log')
axis[1].set_yscale('log')

# %%
print([math.exp(item) for item in x])
print(np.exp(x))
# Out:
# [1.0, 2.718281828459045, 7.38905609893065, 20.085536923187668, 54.598150033144236, 148.4131591025766, 403.4287934927351, 1096.6331584284585, 2980.9579870417283, 8103.083927575384, 22026.465794806718, 59874.14171519782, 162754.79141900392, 442413.3920089205, 1202604.2841647768, 3269017.3724721107, 8886110.520507872, 24154952.7535753, 65659969.13733051, 178482300.96318725]
# [1.00000000e+00 2.71828183e+00 7.38905610e+00 2.00855369e+01
#  5.45981500e+01 1.48413159e+02 4.03428793e+02 1.09663316e+03
#  2.98095799e+03 8.10308393e+03 2.20264658e+04 5.98741417e+04
#  1.62754791e+05 4.42413392e+05 1.20260428e+06 3.26901737e+06
#  8.88611052e+06 2.41549528e+07 6.56599691e+07 1.78482301e+08]

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv('vehicles.csv')
df.head(1)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950

# %%
plt.scatter(df["Combined MPG"], df["Highway MPG"], c='b', marker = '+', alpha = 0.05)

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.boxplot(df['CO2 Emission Grams/Mile'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2585e8dcfd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2585e8df640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2585e8dcc40>],
#  'medians': [<matplotlib.lines.Line2D at 0x2585e8dfe20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2585e8a9100>],
#  'means': []}

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(df['Fuel Barrels/Year'], bins = 20)
plt.show()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
plt.figure(figsize = (10, 6))

plt.bar(df['Fuel Type'], df['City MPG'])
plt.xticks(rotation = 45)

plt.title('FUEL TYPE VS CITY MPG', fontsize = 15)
plt.xlabel('FUEL TYPE', fontsize = 12)
plt.ylabel('CITY MPG', fontsize = 12)
plt.show()
