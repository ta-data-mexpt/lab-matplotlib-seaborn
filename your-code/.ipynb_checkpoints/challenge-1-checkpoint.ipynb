# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.yticks(np.arange(min(y),max(y)+50, 50))
plt.xticks(np.arange(min(x),max(x)+10, 50))
plt.plot(x,y,lw=3,color="g", ls='--')
plt.subplot(1,2,2)
plt.plot(x,z,lw=3, color="r",ls='-')
plt.show()

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig,axes=plt.subplots(1,2)
axes[1].plot(x,y,color="g", lw=4, ls=':')
axes[0].plot(x,z,color="c", lw=2, ls='-.')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig,axes=plt.subplots(1,2, figsize=(10,5))
axes[1].plot(x,y,color="g", lw=4, ls=':')
axes[0].plot(x,z,color="c", lw=2, ls='-.')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig,axes=plt.subplots(1,2, figsize=(10,5))
axes[1].plot(x,y,color="g", lw=4, ls=':')
axes[0].plot(x,z,color="c", lw=2, ls='-.')
axes[0].set_xlabel('X Axis')
axes[0].set_ylabel('Y Axis')
axes[1].set_xlabel('X Axis 2');

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
exp = [math.exp(ele) for ele in x] 

fig,axes=plt.subplots(1,2, figsize=(10,5))
axes[0].plot(x,x**2,color="g", lw=4, ls=':')
axes[0].plot(x,[math.exp(ele) for ele in x],color="b", lw=4, ls='-.')
axes[0].set_xlabel('X Axis')
axes[0].set_ylabel('Y Axis')
axes[1].plot(x,x**2,color="g", lw=4, ls=':')
axes[1].plot(x,[math.exp(ele) for ele in x],color="b", lw=2, ls='-.')
axes[1].set_xlabel('X Axis 2')
axes[1].set_xscale('log')
axes[1].set_yscale('log')

#value : {"linear", "log", "symlog", "logit", ...}

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
vehicles = pd.read_csv('vehicles.csv')

vehicles.columns
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
plt.scatter(vehicles['Combined MPG'],vehicles['Highway MPG'])
plt.xlabel('Combine MPG')
plt.ylabel('Highway MPG')
plt.title('Vehicles');

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.boxplot(vehicles['CO2 Emission Grams/Mile'])
plt.ylabel('CO2 Emission Grams/Mile');

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(vehicles['Fuel Barrels/Year'],bins=10)
# Out:
# (array([8.1000e+01, 3.7400e+02, 6.7650e+03, 1.7039e+04, 8.9660e+03,
#         2.0960e+03, 5.6900e+02, 3.6000e+01, 2.1000e+01, 5.0000e+00]),
#  array([ 0.06      ,  4.76271429,  9.46542857, 14.16814286, 18.87085714,
#         23.57357143, 28.27628571, 32.979     , 37.68171429, 42.38442857,
#         47.08714286]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
vehicles['Fuel Type'].unique().tolist()
# Out:
# ['Regular',
#  'Premium',
#  'Diesel',
#  'Premium and Electricity',
#  'Premium or E85',
#  'Premium Gas or Electricity',
#  'Gasoline or E85',
#  'Gasoline or natural gas',
#  'CNG',
#  'Regular Gas or Electricity',
#  'Midgrade',
#  'Regular Gas and Electricity',
#  'Gasoline or propane']

# %%
vehicles['City MPG'].unique()
# Out:
# array([18, 13, 16, 14, 20, 22, 19, 21, 17, 24, 25, 39, 23, 15, 28, 29, 11,
#        10,  9, 12,  7,  8, 30, 31, 33, 37, 27, 32, 26, 41, 47, 49, 36, 34,
#        38, 44, 35, 43, 40, 42, 50, 45, 48,  6, 51, 54, 58, 53])

# %%
fueltype_mpg=vehicles.pivot_table(index=["Fuel Type"],aggfunc="mean")
fueltype_mpg
# Out:
#                              CO2 Emission Grams/Mile   City MPG  Combined MPG  \
# Fuel Type
# CNG                                       454.976354  15.966667     18.133333
# Diesel                                    470.905819  21.173436     23.488474
# Gasoline or E85                           527.444383  15.347280     17.572385
# Gasoline or natural gas                   638.967778  13.700000     15.350000
# Gasoline or propane                       666.525000  12.000000     13.500000
# Midgrade                                  516.911921  14.851351     17.378378
# Premium                                   481.159270  16.793166     19.343816
# Premium Gas or Electricity                125.411765  30.705882     31.647059
# Premium and Electricity                   239.450000  24.900000     26.300000
# Premium or E85                            460.462355  17.305785     20.090909
# Regular                                   470.907242  17.970195     20.144698
# ...

# %%
plt.bar(fueltype_mpg.index, fueltype_mpg['City MPG'])
plt.title('City MPG')
plt.xticks(rotation = 90);

# %%
city_bar = (vehicles.groupby(vehicle['Fuel type']),sum())
