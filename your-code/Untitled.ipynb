# %%
pip install "jupyterlab>=3" "ipywidgets>=7.6"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install jupyter-dash
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=320aee2cd053c6509f0080fe5e31ddf9eec8ea59f7eac2dfab48f5cda7c7b1eb
#   Stored in directory: c:\users\jfcon\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.
