# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
#las numéricas son las int64 y las float64
titanic_numeric = titanic.select_dtypes(include = ['int64', 'float'])
titanic_numeric
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
#Las categoricas son las object
titanic.select_dtypes(include = ['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic.Age.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
figure, axes = plt.subplots(3)

axes[0].hist(titanic.Age, bins = 10)
axes[1].hist(titanic.Age, bins = 20)
axes[2].hist(titanic.Age, bins = 30)

figure.show()
# Out:
# <ipython-input-8-3fbf90a63534>:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
#Dependiendo del número de bins, los datos se distribuyen entre más rangos, por lo que la acumulación de los datos es menor por cada bin

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.displot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic.Gender.hist()
# Out:
# <AxesSubplot:>

# %%
# your code here- 1st way
fig, x = plt.subplots(1)
x.pie(titanic['Gender'].value_counts(), labels = ['male','female'], autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcc83b85eb0>,
# ...
#  [Text(-0.48083677220945115, 0.9893411941747885, 'male'),
#   Text(0.48083667958064136, -0.9893412391939718, 'female')],
#  [Text(-0.262274603023337, 0.5396406513680664, '64.4%'),
#   Text(0.26227455249853165, -0.5396406759239846, '35.6%')])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
# your code here- 1st way
fig, x = plt.subplots(1)
x.pie(titanic['Pclass'].value_counts(), labels = ['1','2','3'], autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcc501dd130>,
# ...
#  [Text(-0.14346982708627262, 1.0906036900340266, '1'),
#   Text(-0.559877258417352, -0.9468566182411515, '2'),
#   Text(0.865745330250991, -0.678590467917582, '3')],
#  [Text(-0.07825626931978505, 0.5948747400185599, '54.2%'),
#   Text(-0.3053875955003738, -0.5164672463133554, '24.7%'),
#   Text(0.47222472559144957, -0.370140255227772, '21.2%')])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
titanic['Age'].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
# your code here
fig, x = plt.subplots()
x.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcc5014f160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcc5014f820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcc5013edc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcc5014fee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcc5015d280>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#La media está erca de los 30 años.
#El 25% de la población es menor a 22 años.
#El 25% de la población es mayor a 37 años.
#El 50% de la población se encuentra entre 22 y 37 años.
#Existen varias personas cuya edad se consideraría oultier por ser muy grandes.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
titanic.Age.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#La mayoría de la población se encuentra en un rango de entre 18 y 40 años, siendo el rango de entre 24 y 31 el que tiene mas gente.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
fig, x = plt.subplots()
plt.scatter(titanic['Fare'], titanic['Age'])

# %%
# your code-2nd way
sns.scatterplot(data=titanic, x='Fare', y='Age')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
plt.figure(figsize = (20,8))
sns.heatmap(titanic.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#Las dos variables con mayor correlación son Pclass y Fare, seguidas de Pclass y Age y SibSp y Parch

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
multiple_grid = sns.FacetGrid (titanic, col = 'Gender', row = 'Age')
multiple_grid.map(plt.hist, 'Age')
